# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %% [markdown]
# Load Data

# %%
df = pd.read_csv("../data/raw/ikman_cars_raw.csv")

df.head()
# Out:
#                                                  url          price   brand  \
# 0  https://ikman.lk/en/ad/toyota-yaris-2009-for-s...   Rs 5,975,000  Toyota
# 1  https://ikman.lk/en/ad/toyota-land-cruiser-sah...  Rs 46,800,000  Toyota
# 2  https://ikman.lk/en/ad/honda-vezel-hybrid-e-he...  Rs 17,950,000   Honda
# 3  https://ikman.lk/en/ad/kia-sonet-2026-for-sale...  Rs 12,400,000     Kia
# 4  https://ikman.lk/en/ad/toyota-land-cruiser-pra...  Rs 56,000,000  Toyota
#
#                  model    year  condition transmission  body_type fuel_type  \
# 0                Yaris  2009.0       Used    Automatic     Saloon    Petrol
# 1  Land Cruiser Sahara  2011.0       Used    Automatic  SUV / 4x4    Diesel
# 2                Vezel  2026.0  Brand New    Tiptronic  SUV / 4x4    Hybrid
# 3          Other Model  2026.0  Brand New    Automatic  Hatchback    Petrol
# 4   Land Cruiser Prado  2024.0       Used    Automatic  SUV / 4x4    Petrol
#
#   engine_capacity     mileage
# 0        1,300 cc  135,000 km
# 1        4,600 cc   95,000 km
# 2        1,500 cc        0 km
# 3          990 cc        0 km
# 4        2,777 cc    3,200 km

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10819 entries, 0 to 10818
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              10819 non-null  object
#  1   price            10789 non-null  object
#  2   brand            10789 non-null  object
#  3   model            10789 non-null  object
#  4   year             10789 non-null  float64
#  5   condition        10789 non-null  object
#  6   transmission     10789 non-null  object
#  7   body_type        9888 non-null   object
#  8   fuel_type        10789 non-null  object
#  9   engine_capacity  10789 non-null  object
#  10  mileage          10789 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 929.9+ KB
#                                                       url          price  \
# count                                               10819          10789
# unique                                               9174           1633
# top     https://ikman.lk/en/ad/ford-raptor-ranger-ms-r...  Rs 12,500,000
# freq                                                   19             86
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#          brand  model          year condition transmission  body_type  \
# count    10789  10789  10789.000000     10789        10789       9888
# unique      61    502           NaN         4            4          7
# top     Toyota  Vezel           NaN      Used    Automatic  SUV / 4x4
# freq      3747    560           NaN      6073         8666       3452
# mean       NaN    NaN   2016.722124       NaN          NaN        NaN
# std        NaN    NaN     10.259259       NaN          NaN        NaN
# min        NaN    NaN   1950.000000       NaN          NaN        NaN
# 25%        NaN    NaN   2013.000000       NaN          NaN        NaN
# 50%        NaN    NaN   2019.000000       NaN          NaN        NaN
# 75%        NaN    NaN   2024.000000       NaN          NaN        NaN
# max        NaN    NaN   2027.000000       NaN          NaN        NaN
#
#        fuel_type engine_capacity mileage
# count      10789           10789   10789
# unique         6             321    1958
# top       Petrol        1,500 cc    0 km
# freq        7022            2219    2014
# mean         NaN             NaN     NaN
# std          NaN             NaN     NaN
# min          NaN             NaN     NaN
# 25%          NaN             NaN     NaN
# 50%          NaN             NaN     NaN
# 75%          NaN             NaN     NaN
# max          NaN             NaN     NaN

# %% [markdown]
# Clean Price Column

# %%
df["price"] = (
    df["price"]
    .str.replace("Rs", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip()
)

df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %% [markdown]
# Clean Mileage

# %%
df["mileage"] = (
    df["mileage"]
    .str.replace("km", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip()
)

df["mileage"].isnull().sum()
df = df.dropna(subset=["mileage"])
df["mileage"] = df["mileage"].astype(int)

# %% [markdown]
# Clean Engine Capacity

# %%
df["engine_capacity"] = (
    df["engine_capacity"]
    .str.replace("cc", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip()
)

df["engine_capacity"].isnull().sum()
df = df.dropna(subset=["engine_capacity"])
df["engine_capacity"] = df["engine_capacity"].astype(int)

# %% [markdown]
# Fix Year Column

# %%
df["year"].isnull().sum()
df = df.dropna(subset=["year"])
df["year"] = df["year"].astype(int)

# %% [markdown]
# Drop url Column

# %%
df = df.drop(columns=["url"])

# %% [markdown]
# Remove Missing Values

# %%
df.isnull().sum()
df = df.dropna(subset=["price", "year", "mileage", "engine_capacity"])

# %% [markdown]
# Remove Outliers

# %%
df = df[df["year"] >= 1990]
df = df[df["mileage"] < 500000]

Q1 = df['price'].quantile(0.01)
Q3 = df['price'].quantile(0.99)
df = df[(df['price'] >= Q1) & (df['price'] <= Q3)]

df = df[df["engine_capacity"] > 50]

# %% [markdown]
# Fill missing body type values

# %%
df['body_type'] = df['body_type'].fillna('Unknown')

# %% [markdown]
# Feature Engineering - Create car age

# %%
current_year = 2026
df["car_age"] = current_year - df["year"]

# %% [markdown]
# Save Cleaned Dataset

# %%
df.to_csv("../data/processed/cars_cleaned.csv", index=False)
